# %% [markdown]
# <a href="https://colab.research.google.com/github/sabikunjubly/python-mL/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Bangladesh")
# Out:
# Welcome to Bangladesh

# %%
x = 5
y = 14
print( x and y)
# Out:
# 14
